# %%
import pandas as pd
import glob
import re
from functools import reduce

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from collections import Counter

import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
all_files = glob.glob('C:/Users/PC/Desktop/My_Python/8장_data/myCabinetExcelData*.xls')

all_files #출력하여 내용 확인
# Out:
# ['C:/Users/PC/Desktop/My_Python/8장_data\\myCabinetExcelData (1).xls',
#  'C:/Users/PC/Desktop/My_Python/8장_data\\myCabinetExcelData (2).xls',
#  'C:/Users/PC/Desktop/My_Python/8장_data\\myCabinetExcelData (3).xls',
#  'C:/Users/PC/Desktop/My_Python/8장_data\\myCabinetExcelData (4).xls',
#  'C:/Users/PC/Desktop/My_Python/8장_data\\myCabinetExcelData (5).xls',
#  'C:/Users/PC/Desktop/My_Python/8장_data\\myCabinetExcelData (6).xls',
#  'C:/Users/PC/Desktop/My_Python/8장_data\\myCabinetExcelData (7).xls',
#  'C:/Users/PC/Desktop/My_Python/8장_data\\myCabinetExcelData (8).xls',
#  'C:/Users/PC/Desktop/My_Python/8장_data\\myCabinetExcelData (9).xls',
#  'C:/Users/PC/Desktop/My_Python/8장_data\\myCabinetExcelData.xls']

# %%
all_files_data = [] #저장할 리스트 

for file in all_files:
    data_frame = pd.read_excel(file)
    all_files_data.append(data_frame)

all_files_data[0] #출력하여 내용 확인
# Out:
#     Unnamed: 0   번호                                                 제목  \
# 0          NaN    1  Guest Editorial: Big Media Data: Understanding...
# 1          NaN    2  Guest Editorial: Big Scholar Data Discovery an...
# 2          NaN    3    Guest Editorial: Big Data Analytics and the Web
# 3          NaN    4  Parallel computing for preserving privacy usin...
# 4          NaN    5                       NoSQL databases for big data
# ..         ...  ...                                                ...
# 95         NaN   96  Smart city big data analytics: An advanced review
# 96         NaN   97  A watchdog approach - name-matching algorithm ...
# 97         NaN   98  An intelligent approach to Big Data analytics ...
# 98         NaN   99  How organisations leverage Big Data: a maturit...
# 99         NaN  100  Effective and efficient distributed management...
#
#                                                    저자  \
# 0         Wang, J.; Qi, G.; Sebe, N.; Aggarwal, C. C.
# 1          Lin, Y.; Tong, H.; Tang, J.; Candan, K. S.
# 2        Sheng, M.; Vasilakos, A. V.; Yu, Q.; You, L.
# 3                          Yaji, Sharath; Neelima, B.
# 4   Oussous, Ahmed; Benjelloun, Fatima-Zahra; Lahc...
# ..                                                ...
# 95  Soomro, Kamran; Bhutta, Muhammad Nasir Mumtaz;...
# 96                Kirubakaran, Anusuya; Aramudhan, M.
# 97                       Verma, Neha; Singh, Jatinder
# 98                        Comuzzi, Marco; Patel, Anit
# 99  Cuzzocrea, Alfredo; Grasso, Giorgio Mario; Nol...
#
#                                  출판사   출판일
# 0                            unknown  2015
# 1                            unknown  2016
# 2                            unknown  2016
# 3                       Inderscience  2018
# 4                       Inderscience  2017
# ..                               ...   ...
# 95             John Wiley & Sons Ltd  2019
# 96                      Inderscience  2018
# 97  Emerald Group Publishing Limited  2017
# 98  Emerald Group Publishing Limited  2016
# 99                      Inderscience  2019
#
# [100 rows x 6 columns]

# %%
all_files_data_concat = pd.concat(all_files_data, axis=0, ignore_index=True)

all_files_data_concat #출력하여 내용 확인
# Out:
#      Unnamed: 0   번호                                                 제목  \
# 0           NaN    1  Guest Editorial: Big Media Data: Understanding...
# 1           NaN    2  Guest Editorial: Big Scholar Data Discovery an...
# 2           NaN    3    Guest Editorial: Big Data Analytics and the Web
# 3           NaN    4  Parallel computing for preserving privacy usin...
# 4           NaN    5                       NoSQL databases for big data
# ..          ...  ...                                                ...
# 995         NaN   96  Guest Editorial: Big Media Data: Understanding...
# 996         NaN   97  Guest Editorial: Big Scholar Data Discovery an...
# 997         NaN   98  Guest Editorial: Big Media Data: Understanding...
# 998         NaN   99  Speed Up Big Data Analytics by Unveiling the S...
# 999         NaN  100        Architecting Time-Critical Big-Data Systems
#
#                                                     저자           출판사   출판일
# 0          Wang, J.; Qi, G.; Sebe, N.; Aggarwal, C. C.       unknown  2015
# 1           Lin, Y.; Tong, H.; Tang, J.; Candan, K. S.       unknown  2016
# 2         Sheng, M.; Vasilakos, A. V.; Yu, Q.; You, L.       unknown  2016
# 3                           Yaji, Sharath; Neelima, B.  Inderscience  2018
# 4    Oussous, Ahmed; Benjelloun, Fatima-Zahra; Lahc...  Inderscience  2017
# ..                                                 ...           ...   ...
# 995           Wang, J.; Qi, G.; Sebe, N.; Aggarwal, C.       unknown  2017
# 996         Lin, Y.; Tong, H.; Tang, J.; Candan, K. S.       unknown  2017
# 997        Wang, J.; Qi, G.; Sebe, N.; Aggarwal, C. C.       unknown  2016
# 998  Wang, J.; Zhang, X.; Yin, J.; Wang, R.; Wu, H....       unknown  2018
# 999  Basanta-Val, P.; Audsley, N. C.; Wellings, A. ...       unknown  2016
#
# [1000 rows x 6 columns]

# %%
all_files_data_concat.to_csv('C:/Users/PC/Desktop/My_Python/8장_data/riss_bigdata.csv', encoding='utf-8', index = False)

# %%
# 제목 추출
all_title = all_files_data_concat['제목']

all_title #출력하여 내용 확인
# Out:
# 0      Guest Editorial: Big Media Data: Understanding...
# 1      Guest Editorial: Big Scholar Data Discovery an...
# 2        Guest Editorial: Big Data Analytics and the Web
# 3      Parallel computing for preserving privacy usin...
# 4                           NoSQL databases for big data
#                              ...
# 995    Guest Editorial: Big Media Data: Understanding...
# 996    Guest Editorial: Big Scholar Data Discovery an...
# 997    Guest Editorial: Big Media Data: Understanding...
# 998    Speed Up Big Data Analytics by Unveiling the S...
# 999          Architecting Time-Critical Big-Data Systems
# Name: 제목, Length: 1000, dtype: object

# %%
# 제목 추출
all_title = all_files_data_concat['제목']

all_title #출력하여 내용 확인
# Out:
# 0      Guest Editorial: Big Media Data: Understanding...
# 1      Guest Editorial: Big Scholar Data Discovery an...
# 2        Guest Editorial: Big Data Analytics and the Web
# 3      Parallel computing for preserving privacy usin...
# 4                           NoSQL databases for big data
#                              ...
# 995    Guest Editorial: Big Media Data: Understanding...
# 996    Guest Editorial: Big Scholar Data Discovery an...
# 997    Guest Editorial: Big Media Data: Understanding...
# 998    Speed Up Big Data Analytics by Unveiling the S...
# 999          Architecting Time-Critical Big-Data Systems
# Name: 제목, Length: 1000, dtype: object

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
all_title = all_files_data_concat['제목']

# %%
stopWords = set(stopwords.words("english"))
lemma = WordNetLemmatizer()

# %%
words = []

# %%
for title in all_title:
    EnWords = re.sub(r"[^a-zA-Z]+", " ", str(title))    
    EnWordsToken = word_tokenize(EnWords.lower())
    EnWordsTokenStop = [w for w in EnWordsToken if w not in stopWords]
    EnWordsTokenStopLemma = [lemma.lemmatize(w) for w in EnWordsTokenStop]
    words.append(EnWordsTokenStopLemma)

# %%
print(words)
# Out:
# [['guest', 'editorial', 'big', 'medium', 'data', 'understanding', 'search', 'mining', 'part'], ['guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration'], ['guest', 'editorial', 'big', 'data', 'analytics', 'web'], ['parallel', 'computing', 'preserving', 'privacy', 'using', 'k', 'anonymisation', 'algorithm', 'big', 'data'], ['nosql', 'database', 'big', 'data'], ['computation', 'migration', 'new', 'approach', 'execute', 'big', 'data', 'bioinformatics', 'workflow'], ['towards', 'real', 'time', 'big', 'data', 'analytics', 'platform', 'health', 'application'], ['new', 'approach', 'accurate', 'distributed', 'cluster', 'analysis', 'big', 'data', 'competitive', 'k', 'mean'], ['five', 'layer', 'architecture', 'big', 'data', 'processing', 'analytics'], ['towards', 'max', 'min', 'fair', 'resource', 'allocation', 'stream', 'big', 'data', 'analytics', 'shared', 'cloud'], ['large', 'scale', 'spectral', 'clustering', 'managing', 'big', 'data', 'healthcare', 'operation'], ['hierarchical', 'distributed', 'processing', 'framework', 'big', 'image', 'data'], ['platform', 'big', 'data', 'analytics', 'distributed', 'scale', 'storage', 'system'], ['online', 'similarity', 'learning', 'big', 'data', 'overfitting'], ['towards', 'quality', 'service', 'driven', 'consistency', 'big', 'data', 'management'], ['platform', 'big', 'data', 'analytics', 'distributed', 'scale', 'storage', 'system'], ['current', 'trend', 'predictive', 'analytics', 'big', 'data'], ['classification', 'comparison', 'nosql', 'big', 'data', 'model'], ['survey', 'big', 'data', 'processing', 'infrastructure', 'evolving', 'role', 'fpga'], ['fast', 'approach', 'semantic', 'service', 'composition', 'big', 'data', 'environment'], ['secure', 'multi', 'owner', 'based', 'cloud', 'computing', 'scheme', 'big', 'data'], ['corporate', 'governance', 'fraud', 'detection', 'annual', 'report', 'using', 'big', 'data', 'analytics'], ['fuzzy', 'based', 'scalable', 'clustering', 'algorithm', 'handling', 'big', 'data', 'using', 'apache', 'spark'], ['privacy', 'model', 'big', 'data', 'survey'], ['towards', 'quality', 'service', 'driven', 'consistency', 'big', 'data', 'management'], ['new', 'approach', 'accurate', 'distributed', 'cluster', 'analysis', 'big', 'data', 'competitive', 'k', 'mean'], ['palopro', 'platform', 'knowledge', 'extraction', 'big', 'social', 'data', 'news'], ['index', 'ieee', 'transaction', 'big', 'data', 'vol'], ['hybridisation', 'classifier', 'anomaly', 'detection', 'big', 'data'], ['toward', 'efficient', 'flexible', 'metadata', 'indexing', 'big', 'data', 'system'], ['structural', 'balance', 'theory', 'based', 'e', 'commerce', 'recommendation', 'big', 'rating', 'data'], ['petuum', 'new', 'platform', 'distributed', 'machine', 'learning', 'big', 'data'], ['special', 'issue', 'biomedical', 'big', 'data', 'understanding', 'learning', 'application'], ['smart', 'monitoring', 'camera', 'driven', 'intelligent', 'processing', 'big', 'surveillance', 'video', 'data'], ['distributed', 'feature', 'selection', 'efficient', 'economic', 'big', 'data', 'analysis'], ['extended', 'spatio', 'temporal', 'granger', 'causality', 'model', 'air', 'quality', 'estimation', 'heterogeneous', 'urban', 'big', 'data'], ['hdm', 'composable', 'framework', 'big', 'data', 'processing'], ['index', 'ieee', 'transaction', 'big', 'data', 'vol'], ['enhanced', 'visualization', 'method', 'aid', 'behavioral', 'trajectory', 'pattern', 'recognition', 'infrastructure', 'big', 'longitudinal', 'data'], ['dip', 'svm', 'distribution', 'preserving', 'kernel', 'support', 'vector', 'machine', 'big', 'data'], ['availability', 'modelling', 'assurance', 'big', 'data', 'computing'], ['deduplication', 'encrypted', 'big', 'data', 'cloud'], ['guest', 'editorial', 'special', 'issue', 'big', 'scholar', 'data', 'discovery', 'collaboration', 'continued'], ['kvasir', 'scalable', 'provision', 'semantically', 'relevant', 'web', 'content', 'big', 'data', 'framework'], ['perception', 'independent', 'financial', 'advisor', 'usefulness',  ...

# %%
words2 = list(reduce(lambda x, y: x+y,words))
print(words2)  #작업 내용 확인
# Out:
# ['guest', 'editorial', 'big', 'medium', 'data', 'understanding', 'search', 'mining', 'part', 'guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration', 'guest', 'editorial', 'big', 'data', 'analytics', 'web', 'parallel', 'computing', 'preserving', 'privacy', 'using', 'k', 'anonymisation', 'algorithm', 'big', 'data', 'nosql', 'database', 'big', 'data', 'computation', 'migration', 'new', 'approach', 'execute', 'big', 'data', 'bioinformatics', 'workflow', 'towards', 'real', 'time', 'big', 'data', 'analytics', 'platform', 'health', 'application', 'new', 'approach', 'accurate', 'distributed', 'cluster', 'analysis', 'big', 'data', 'competitive', 'k', 'mean', 'five', 'layer', 'architecture', 'big', 'data', 'processing', 'analytics', 'towards', 'max', 'min', 'fair', 'resource', 'allocation', 'stream', 'big', 'data', 'analytics', 'shared', 'cloud', 'large', 'scale', 'spectral', 'clustering', 'managing', 'big', 'data', 'healthcare', 'operation', 'hierarchical', 'distributed', 'processing', 'framework', 'big', 'image', 'data', 'platform', 'big', 'data', 'analytics', 'distributed', 'scale', 'storage', 'system', 'online', 'similarity', 'learning', 'big', 'data', 'overfitting', 'towards', 'quality', 'service', 'driven', 'consistency', 'big', 'data', 'management', 'platform', 'big', 'data', 'analytics', 'distributed', 'scale', 'storage', 'system', 'current', 'trend', 'predictive', 'analytics', 'big', 'data', 'classification', 'comparison', 'nosql', 'big', 'data', 'model', 'survey', 'big', 'data', 'processing', 'infrastructure', 'evolving', 'role', 'fpga', 'fast', 'approach', 'semantic', 'service', 'composition', 'big', 'data', 'environment', 'secure', 'multi', 'owner', 'based', 'cloud', 'computing', 'scheme', 'big', 'data', 'corporate', 'governance', 'fraud', 'detection', 'annual', 'report', 'using', 'big', 'data', 'analytics', 'fuzzy', 'based', 'scalable', 'clustering', 'algorithm', 'handling', 'big', 'data', 'using', 'apache', 'spark', 'privacy', 'model', 'big', 'data', 'survey', 'towards', 'quality', 'service', 'driven', 'consistency', 'big', 'data', 'management', 'new', 'approach', 'accurate', 'distributed', 'cluster', 'analysis', 'big', 'data', 'competitive', 'k', 'mean', 'palopro', 'platform', 'knowledge', 'extraction', 'big', 'social', 'data', 'news', 'index', 'ieee', 'transaction', 'big', 'data', 'vol', 'hybridisation', 'classifier', 'anomaly', 'detection', 'big', 'data', 'toward', 'efficient', 'flexible', 'metadata', 'indexing', 'big', 'data', 'system', 'structural', 'balance', 'theory', 'based', 'e', 'commerce', 'recommendation', 'big', 'rating', 'data', 'petuum', 'new', 'platform', 'distributed', 'machine', 'learning', 'big', 'data', 'special', 'issue', 'biomedical', 'big', 'data', 'understanding', 'learning', 'application', 'smart', 'monitoring', 'camera', 'driven', 'intelligent', 'processing', 'big', 'surveillance', 'video', 'data', 'distributed', 'feature', 'selection', 'efficient', 'economic', 'big', 'data', 'analysis', 'extended', 'spatio', 'temporal', 'granger', 'causality', 'model', 'air', 'quality', 'estimation', 'heterogeneous', 'urban', 'big', 'data', 'hdm', 'composable', 'framework', 'big', 'data', 'processing', 'index', 'ieee', 'transaction', 'big', 'data', 'vol', 'enhanced', 'visualization', 'method', 'aid', 'behavioral', 'trajectory', 'pattern', 'recognition', 'infrastructure', 'big', 'longitudinal', 'data', 'dip', 'svm', 'distribution', 'preserving', 'kernel', 'support', 'vector', 'machine', 'big', 'data', 'availability', 'modelling', 'assurance', 'big', 'data', 'computing', 'deduplication', 'encrypted', 'big', 'data', 'cloud', 'guest', 'editorial', 'special', 'issue', 'big', 'scholar', 'data', 'discovery', 'collaboration', 'continued', 'kvasir', 'scalable', 'provision', 'semantically', 'relevant', 'web', 'content', 'big', 'data', 'framework', 'perception', 'independent', 'financial', 'advisor', 'usefulness', 'big', 'data', 'context', 'decision', 'making', 'uk', 'optimized', 'deep', 'learning', 'e ...

# %%
count = Counter(words2)

count   #출력하여 내용 확인
# Out:
# Counter({'data': 1645,
#          'big': 1354,
#          'analytics': 137,
#          'analysis': 67,
#          'based': 62,
#          'using': 57,
#          'system': 50,
#          'science': 50,
#          'management': 48,
#          'challenge': 47,
#          'approach': 44,
#          'mining': 40,
#          'new': 38,
#          'research': 38,
#          'health': 37,
#          'model': 37,
#          'cloud': 34,
#          'smart': 34,
#          'learning': 33,
#          'opportunity': 31,
#          'processing': 30,
#          'technology': 28,
#          'small': 27,
#          'framework': 26,
#          'information': 26,
#          'computing': 25,
#          'application': 25,
#          'driven': 24,
#          'social': 24,
#          'issue': 24,
#          'quality': 23,
#          'network': 23,
#          'deal': 23,
#          'knowledge': 22,
#          'efficient': 22,
#          'review': 22,
#          'use': 22,
#          'era': 22,
#          'healthcare': 21,
#          'storage': 21,
#          'service': 21,
#          'perspective': 21,
#          'open': 20,
#          'platform': 19,
#          'survey': 19,
#          'making': 19,
#          'process': 19,
#          'distributed': 18,
#          'large': 18,
#          'environment': 18,
#          'method': 18,
#          'decision': 18,
#          'business': 18,
#          'market': 18,
#          'editorial': 17,
#          'privacy': 17,
#          'algorithm': 17,
#          'time': 17,
#          'care': 17,
#          'city': 17,
#          'question': 16,
#          'world': 16,
#          'earth': 16,
#          'machine': 15,
#          'insight': 15,
#          'value': 15,
#          'company': 15,
#          'need': 15,
#          'real': 14,
#          'predictive': 14,
#          'warehouse': 14,
#          'law': 14,
#          'design': 14,
#          'sharing': 14,
#          'potential': 14,
#          'discovery': 13,
#          'scalable': 13,
#          'urban': 13,
#          'prediction': 13,
#          'case': 13,
#          'problem': 13,
#          'future': 13,
#          'solution': 13,
#          'promise': 13,
#          'protection': 13,
#          'picture': 13,
#          'guest': 12,
#          'towards': 12,
#          'scale': 12,
#          'infrastructure': 12,
#          'special': 12,
#          'security': 12,
#          'meet': 12,
#          'risk': 12,
#          'strategy': 12,
#          'tool': 12,
#          'u': 12,
#          'way': 12,
#          'center': 12,
#          'next': 12,
#          'little': 12,
#          'medium': 11,
#          'understanding': 11,
#          'database': 11,
#          'architecture': 11,
#          'multi': 11,
#          'thing': 11,
#          'modeling': 11,
#          'industry': 11,
#          'patient': 11,
#          'study': 11,
#          'public': 11,
#          'role': 10,
#          'internet': 10,
#          'graph': 10,
#          'spatial': 10,
#          'clinical': 10,
#          'set': 10,
#          'impact': 10,
#          'make': 10,
#          'energy': 10,
#          'digital': 10,
#          'human': 10,
#          'introduction': 10,
#          'performance': 10,
#          'state': 10,
#          'device': 10,
#          'practice': 10,
#          'web': 9,
#          'mean': 9,
#          'theory': 9,
#          'support': 9,
#          'intelligence': 9,
#          'source': 9,
#          'aware': 9,
#          'change': 9,
#          'innovation': 9,
#          'chain': 9,
#          'improve': 9,
#          'best': 9,
#          'scientist': 9,
#          'call': 9,
#          'control': 9,
#          'stream': 8,
#          'classification': 8,
#          'sector': 8,
#          'development': 8,
#          'librarian': 8,
#          'benefit': 8,
#          'building': 8,
#          'government': 8,
#          'help': 8,
#          'money': 8,
#          'software': 8,
#          'project': 8,
#          'optimization': 8,
#          'revolution': 8,
#          'collection': 8,
#          'mobile': 8,
#          'paper': 8,
#          'search': 7,
#          'k': 7,
#          'clustering': 7,
#          'online': 7,
#          'semantic': 7,
#          'report': 7,
#          'toward': 7,
#          'e': 7,
#          'monitoring': 7,
#          'intelligent': 7,
#          'heterogeneous': 7,
#          'distribution': 7,
#          'financial': 7,
#          'context': 7,
#          'sensor': 7,
#          'international': 7,
#          'mapreduce': 7,
#          'hadoop': 7,
#          'bigger': 7,
#          'technique': 7,
#          'emerging': 7,
#          'sensing': 7,
#          'effective': 7,
#          'dynamic': 7,
#          'analyzing': 7,
#          'high': 7,
#          'legal': 7,
#          'creating': 7,
#          'good': 7,
#          'amp': 7,
#          'work': 7,
#          'gain': 7,
#          'really': 7,
#          'generation': 7,
#          'brother': 7,
#          'consumer': 7,
#          'supply': 7,
#          'flow': 7,
#          'remote': 7,
#          'leveraging': 7,
#          'treatment': 7,
#          'planning': 7,
#          'get': 7,
#          'field': 7,
#          'thinking': 7,
#          'competitive': 6,
#          'operation': 6,
#          'trend': 6,
#          'fraud': 6,
#          'detection': 6,
#          'metadata': 6,
#          'temporal': 6,
#          'visualization': 6,
#          'demand': 6,
#          'applying': 6,
#          'enabled': 6,
#          'biggest': 6,
#          'linked': 6,
#          'practical': 6,
#          'scientific': 6,
#          'volume': 6,
#          'measurement': 6,
#          'query': 6,
#          'sentiment': 6,
#          'evidence': 6,
#          'consequence': 6,
#          'offer': 6,
#          'provides': 6,
#          'becoming': 6,
#          'implication': 6,
#          'hype': 6,
#          'finding': 6,
#          'space': 6,
#          'marketer': 6,
#          'know': 6,
#          'centre': 6,
#          'manufacturing': 6,
#          'scholarship': 6,
#          'biology': 6,
#          'medical': 6,
#          'pitfall': 6,
#          'representation': 6,
#          'expert': 6,
#          'product': 6,
#          'life': 6,
#          'individual': 6,
#          'political': 6,
#          'end': 6,
#          'education': 6,
#          'tell': 6,
#          'visual': 6,
#          'collaboration': 5,
#          'parallel': 5,
#          'resource': 5,
#          'current': 5,
#          'fast': 5,
#          'handling': 5,
#          'deep': 5,
#          'enterprise': 5,
#          'engineering': 5,
#          'first': 5,
#          'conference': 5,
#          'result': 5,
#          'repository': 5,
#          'assessment': 5,
#          'memory': 5,
#          'exploring': 5,
#          'team': 5,
#          'eu': 5,
#          'semantics': 5,
#          'forecasting': 5,
#          'china': 5,
#          'integration': 5,
#          'advanced': 5,
#          'factory': 5,
#          'global': 5,
#          'p': 5,
#          'student': 5,
#          'green': 5,
#          'pp': 5,
#          'improved': 5,
#          'customer': 5,
#          'personal': 5,
#          'advance': 5,
#          'cost': 5,
#          'networked': 5,
#          'l': 5,
#          'intensive': 5,
#          'outcome': 5,
#          'experience': 5,
#          'marketing': 5,
#          'datasets': 5,
#          'imaging': 5,
#          'discus': 5,
#          'evaluation': 5,
#          'structure': 5,
#          'medicine': 5,
#          'policy': 5,
#          'user': 5,
#          'computer': 5,
#          'iot': 5,
#          'multiple': 5,
#          'computational': 5,
#          'professional': 5,
#          'capture': 5,
#          'say': 5,
#          'mapping': 5,
#          'versus': 5,
#          'rethinking': 5,
#          'nosql': 4,
#          'migration': 4,
#          'five': 4,
#          'managing': 4,
#          'image': 4,
#          'governance': 4,
#          'extraction': 4,
#          'index': 4,
#          'indexing': 4,
#          'behavioral': 4,
#          'scholarly': 4,
#          'communication': 4,
#          'improving': 4,
#          'map': 4,
#          'dimension': 4,
#          'bayesian': 4,
#          'condition': 4,
#          'power': 4,
#          'plant': 4,
#          'novel': 4,
#          'ontology': 4,
#          'sustainable': 4,
#          'leverage': 4,
#          'twitter': 4,
#          'wireless': 4,
#          'divide': 4,
#          'overview': 4,
#          'view': 4,
#          'comprehensive': 4,
#          'join': 4,
#          'sparse': 4,
#          'measure': 4,
#          'sample': 4,
#          'transforming': 4,
#          'pre': 4,
#          'look': 4,
#          'example': 4,
#          'must': 4,
#          'bang': 4,
#          'four': 4,
#          'pain': 4,
#          'long': 4,
#          'isbn': 4,
#          'action': 4,
#          'coming': 4,
#          'tech': 4,
#          'turning': 4,
#          'boost': 4,
#          'european': 4,
#          'concern': 4,
#          'recent': 4,
#          'among': 4,
#          'asset': 4,
#          'want': 4,
#          'industrial': 4,
#          'efficiency': 4,
#          'plan': 4,
#          'discussion': 4,
#          'training': 4,
#          'safety': 4,
#          'preliminary': 4,
#          'advantage': 4,
#          'massive': 4,
#          'creation': 4,
#          'article': 4,
#          'number': 4,
#          'relationship': 4,
#          'statistical': 4,
#          'stroke': 4,
#          'complex': 4,
#          'genomics': 4,
#          'task': 4,
#          'scheduling': 4,
#          'useful': 4,
#          'course': 4,
#          'society': 4,
#          'generated': 4,
#          'ethic': 4,
#          'internal': 4,
#          'critical': 4,
#          'c': 4,
#          'radiation': 4,
#          'general': 4,
#          'disaster': 4,
#          'warehousing': 4,
#          'national': 4,
#          'simulation': 4,
#          'bank': 4,
#          'economy': 4,
#          'brain': 4,
#          'connected': 4,
#          'people': 4,
#          'satellite': 4,
#          'disease': 4,
#          'multimedia': 4,
#          'trial': 4,
#          'hybrid': 4,
#          'partitioning': 4,
#          'answer': 4,
#          'experiment': 4,
#          'robotics': 4,
#          'visualisation': 4,
#          'gap': 4,
#          'scholar': 3,
#          'workflow': 3,
#          'accurate': 3,
#          'allocation': 3,
#          'evolving': 3,
#          'scheme': 3,
#          'spark': 3,
#          'structural': 3,
#          'biomedical': 3,
#          'camera': 3,
#          'selection': 3,
#          'economic': 3,
#          'extended': 3,
#          'air': 3,
#          'trajectory': 3,
#          'pattern': 3,
#          'longitudinal': 3,
#          'kernel': 3,
#          'modelling': 3,
#          'assurance': 3,
#          'content': 3,
#          'independent': 3,
#          'extracting': 3,
#          'investigation': 3,
#          'transportation': 3,
#          'fusion': 3,
#          'phase': 3,
#          'academic': 3,
#          'skill': 3,
#          'always': 3,
#          'physical': 3,
#          'level': 3,
#          'done': 3,
#          'designing': 3,
#          'better': 3,
#          'em': 3,
#          'grid': 3,
#          'sdn': 3,
#          'michael': 3,
#          'buck': 3,
#          'alternative': 3,
#          'face': 3,
#          'used': 3,
#          'sampling': 3,
#          'methodology': 3,
#          'incremental': 3,
#          'conquer': 3,
#          'effect': 3,
#          'nearest': 3,
#          'store': 3,
#          'virtual': 3,
#          'supporting': 3,
#          'uncertainty': 3,
#          'community': 3,
#          'bias': 3,
#          'correction': 3,
#          'pipeline': 3,
#          'v': 3,
#          'stay': 3,
#          'whether': 3,
#          'concept': 3,
#          'hard': 3,
#          'growing': 3,
#          'population': 3,
#          'year': 3,
#          'climate': 3,
#          'lawyer': 3,
#          'huge': 3,
#          'quantity': 3,
#          'headache': 3,
#          'job': 3,
#          'assessing': 3,
#          'defined': 3,
#          'networking': 3,
#          'hope': 3,
#          'early': 3,
#          'politics': 3,
#          'r': 3,
#          'present': 3,
#          'brand': 3,
#          'see': 3,
#          'implementing': 3,
#          'pathway': 3,
#          'foundation': 3,
#          'firm': 3,
#          'analytical': 3,
#          'capability': 3,
#          'idea': 3,
#          'message': 3,
#          'utility': 3,
#          'extract': 3,
#          'gold': 3,
#          'save': 3,
#          'crunch': 3,
#          'access': 3,
#          'modern': 3,
#          'behind': 3,
#          'acquisition': 3,
#          'explains': 3,
#          'united': 3,
#          'movement': 3,
#          'series': 3,
#          'audit': 3,
#          'regulation': 3,
#          'regulatory': 3,
#          'create': 3,
#          'record': 3,
#          'precision': 3,
#          'informatics': 3,
#          'cardiovascular': 3,
#          'material': 3,
#          'drug': 3,
#          'book': 3,
#          'chemistry': 3,
#          'two': 3,
#          'consideration': 3,
#          'analytic': 3,
#          'jonathan': 3,
#          'kettleborough': 3,
#          'epidemiology': 3,
#          'navigating': 3,
#          'sport': 3,
#          'automated': 3,
#          'organization': 3,
#          'combining': 3,
#          'trauma': 3,
#          'f': 3,
#          'signal': 3,
#          'brazilian': 3,
#          'age': 3,
#          'enabling': 3,
#          'throughput': 3,
#          'three': 3,
#          'rate': 3,
#          'actionable': 3,
#          'everywhere': 3,
#          'myth': 3,
#          'different': 3,
#          'crime': 3,
#          'operator': 3,
#          'reference': 3,
#          'landscape': 3,
#          'archive': 3,
#          'fda': 3,
#          'unstructured': 3,
#          'test': 3,
#          'profile': 3,
#          'combat': 3,
#          'integrity': 3,
#          'day': 3,
#          'package': 3,
#          'german': 3,
#          'alzheimer': 3,
#          'initiative': 3,
#          'factor': 3,
#          'disorder': 3,
#          'production': 3,
#          'coding': 3,
#          'harnessing': 3,
#          'bi': 3,
#          'epilepsy': 3,
#          'perform': 3,
#          'methodological': 3,
#          'effort': 3,
#          'artificial': 3,
#          'prescription': 3,
#          'australia': 3,
#          'crowdsourcing': 3,
#          'electronic': 3,
#          'collected': 3,
#          'therapy': 3,
#          'read': 3,
#          'across': 3,
#          'connecting': 3,
#          'rich': 3,
#          'key': 3,
#          'backlash': 3,
#          'sublime': 3,
#          'diagrammatic': 3,
#          'many': 3,
#          'vast': 3,
#          'capacity': 3,
#          'come': 3,
#          'provenance': 3,
#          'electric': 3,
#          'lab': 3,
#          'everybody': 3,
#          'lie': 3,
#          'retrieval': 3,
#          'geospatial': 3,
#          'actually': 3,
#          'variable': 3,
#          'propaganda': 3,
#          'preserving': 2,
#          'computation': 2,
#          'bioinformatics': 2,
#          'cluster': 2,
#          'fair': 2,
#          'shared': 2,
#          'spectral': 2,
#          'similarity': 2,
#          'consistency': 2,
#          'secure': 2,
#          'corporate': 2,
#          'fuzzy': 2,
#          'apache': 2,
#          'news': 2,
#          'ieee': 2,
#          'transaction': 2,
#          'vol': 2,
#          'anomaly': 2,
#          'flexible': 2,
#          'commerce': 2,
#          'recommendation': 2,
#          'surveillance': 2,
#          'video': 2,
#          'feature': 2,
#          'causality': 2,
#          'enhanced': 2,
#          'vector': 2,
#          'deduplication': 2,
#          'encrypted': 2,
#          'semantically': 2,
#          'relevant': 2,
#          'perception': 2,
#          'uk': 2,
#          'optimized': 2,
#          'seizure': 2,
#          'via': 2,
#          'taxonomy': 2,
#          'hotel': 2,
#          'programming': 2,
#          'yield': 2,
#          'coping': 2,
#          'dws': 2,
#          'implicit': 2,
#          'paradigm': 2,
#          'operating': 2,
#          'mine': 2,
#          'catalyst': 2,
#          'build': 2,
#          'tensor': 2,
#          'reduction': 2,
#          'dream': 2,
#          'shake': 2,
#          'error': 2,
#          'recovery': 2,
#          'detailed': 2,
#          'compression': 2,
#          'rule': 2,
#          'compute': 2,
#          'mobility': 2,
#          'scenario': 2,
#          'retail': 2,
#          'maturity': 2,
#          'evaluating': 2,
#          'stakeholder': 2,
#          'word': 2,
#          'barrier': 2,
#          'regression': 2,
#          'advancing': 2,
#          'step': 2,
#          'generalized': 2,
#          'correlation': 2,
#          'stock': 2,
#          'direction': 2,
#          'theoretical': 2,
#          'experimental': 2,
#          'dimensional': 2,
#          'approximate': 2,
#          'sequence': 2,
#          'neighbor': 2,
#          'group': 2,
#          'non': 2,
#          'simple': 2,
#          'made': 2,
#          'addressing': 2,
#          'personalized': 2,
#          'raise': 2,
#          'cause': 2,
#          'major': 2,
#          'prevent': 2,
#          'school': 2,
#          'think': 2,
#          'identifying': 2,
#          'administrative': 2,
#          'conceptual': 2,
#          'latin': 2,
#          'develop': 2,
#          'york': 2,
#          'aim': 2,
#          'protecting': 2,
#          'benchmark': 2,
#          'function': 2,
#          'pay': 2,
#          'swd': 2,
#          'improvement': 2,
#          'provider': 2,
#          'unlock': 2,
#          'unleash': 2,
#          'like': 2,
#          'clinic': 2,
#          'transform': 2,
#          'reform': 2,
#          'president': 2,
#          'giant': 2,
#          'low': 2,
#          'metering': 2,
#          'christine': 2,
#          'borgman': 2,
#          'unit': 2,
#          'substance': 2,
#          'progress': 2,
#          'private': 2,
#          'forum': 2,
#          'vehicle': 2,
#          'usage': 2,
#          'jay': 2,
#          'inamdar': 2,
#          'university': 2,
#          'common': 2,
#          'astronomy': 2,
#          'interview': 2,
#          'claim': 2,
#          'would': 2,
#          'broadcast': 2,
#          'reveals': 2,
#          'examines': 2,
#          'scope': 2,
#          'dilemma': 2,
#          'local': 2,
#          'compliance': 2,
#          'optic': 2,
#          'ability': 2,
#          'exploit': 2,
#          'worldwide': 2,
#          'edge': 2,
#          'agriculture': 2,
#          'rise': 2,
#          'answering': 2,
#          'aggregation': 2,
#          'abstract': 2,
#          'ensure': 2,
#          'mistake': 2,
#          'limitation': 2,
#          'researcher': 2,
#          'begin': 2,
#          'chaos': 2,
#          'considering': 2,
#          'derive': 2,
#          'place': 2,
#          'event': 2,
#          'called': 2,
#          'third': 2,
#          'highlight': 2,
#          'vendor': 2,
#          'built': 2,
#          'capital': 2,
#          'investment': 2,
#          'concerning': 2,
#          'supported': 2,
#          'federal': 2,
#          'athlete': 2,
#          'respond': 2,
#          'oil': 2,
#          'gas': 2,
#          'neuroscience': 2,
#          'activity': 2,
#          'wearable': 2,
#          'benchmarking': 2,
#          'europe': 2,
#          'mary': 2,
#          'nurse': 2,
#          'pollution': 2,
#          'verification': 2,
#          'imperfect': 2,
#          'organizational': 2,
#          'equipment': 2,
#          'provide': 2,
#          'address': 2,
#          'bring': 2,
#          'transfer': 2,
#          'us': 2,
#          'citizen': 2,
#          'reaction': 2,
#          'campaign': 2,
#          'blue': 2,
#          'fact': 2,
#          'code': 2,
#          'valuable': 2,
#          'integrating': 2,
#          'various': 2,
#          'parameter': 2,
#          'layered': 2,
#          'variety': 2,
#          'teaching': 2,
#          'auditor': 2,
#          'regulating': 2,
#          'maintenance': 2,
#          'reliability': 2,
#          'savvy': 2,
#          'allow': 2,
#          'solar': 2,
#          'institution': 2,
#          'litigation': 2,
#          'reprocessing': 2,
#          'goal': 2,
#          'council': 2,
#          'enhance': 2,
#          'cybersecurity': 2,
#          'easy': 2,
#          'stochastic': 2,
#          'robust': 2,
#          'month': 2,
#          'getting': 2,
#          'resolution': 2,
#          'program': 2,
#          'add': 2,
#          'bd': 2,
#          'within': 2,
#          'rob': 2,
#          'beat': 2,
#          'architecting': 2,
#          'order': 2,
#          'mixed': 2,
#          'enough': 2,
#          'child': 2,
#          'shock': 2,
#          'primary': 2,
#          'topology': 2,
#          'protein': 2,
#          'guiding': 2,
#          'much': 2,
#          'tackle': 2,
#          'mind': 2,
#          'amount': 2,
#          'commercial': 2,
#          'observation': 2,
#          'aerospace': 2,
#          'contribution': 2,
#          'strategic': 2,
#          'engineer': 2,
#          'putting': 2,
#          'fire': 2,
#          'weather': 2,
#          'preparing': 2,
#          'water': 2,
#          'traditional': 2,
#          'panel': 2,
#          'army': 2,
#          'forensic': 2,
#          'anesthesiology': 2,
#          'party': 2,
#          'line': 2,
#          'buzz': 2,
#          'transmission': 2,
#          'mit': 2,
#          'labelling': 2,
#          'id': 2,
#          'town': 2,
#          'one': 2,
#          'faster': 2,
#          'transformation': 2,
#          'enriched': 2,
#          'consumption': 2,
#          'force': 2,
#          'consent': 2,
#          'anonymise': 2,
#          'tourism': 2,
#          'behavior': 2,
#          'introducing': 2,
#          'increasingly': 2,
#          'success': 2,
#          'protect': 2,
#          'grows': 2,
#          'discrete': 2,
#          'template': 2,
#          'centric': 2,
#          'linking': 2,
#          'ecosystem': 2,
#          'augmenting': 2,
#          'matter': 2,
#          'target': 2,
#          'critique': 2,
#          'cover': 2,
#          'sphere': 2,
#          'maximum': 2,
#          'ensemble': 2,
#          'noise': 2,
#          'filtering': 2,
#          'pca': 2,
#          'combine': 2,
#          'emergent': 2,
#          'realizing': 2,
#          'meta': 2,
#          'tracing': 2,
#          'origin': 2,
#          'bibliometrics': 2,
#          'opac': 2,
#          'remain': 2,
#          'biobanking': 2,
#          'oncology': 2,
#          'humanizing': 2,
#          'meeting': 2,
#          'strong': 2,
#          'london': 2,
#          'kogan': 2,
#          'page': 2,
#          'realize': 2,
#          'beginning': 2,
#          'tree': 2,
#          'b': 2,
#          'smaller': 2,
#          'economist': 2,
#          'saving': 2,
#          'generating': 2,
#          'routinely': 2,
#          'modulated': 2,
#          'arc': 2,
#          'intensity': 2,
#          'sense': 2,
#          'master': 2,
#          'azure': 2,
#          'thick': 2,
#          'understand': 2,
#          'aircraft': 2,
#          'ai': 2,
#          'clean': 2,
#          'profit': 2,
#          'cleaning': 2,
#          'mouse': 2,
#          'badge': 2,
#          'cv': 2,
#          'measured': 2,
#          'topological': 2,
#          'probabilistic': 2,
#          'utilizing': 2,
#          'spatiotemporal': 2,
#          'preprocessing': 2,
#          'responsibility': 2,
#          'north': 2,
#          'deluge': 2,
#          'tomorrow': 2,
#          'securing': 2,
#          'box': 2,
#          'reliable': 2,
#          'manufacturer': 2,
#          'available': 2,
#          'chemical': 2,
#          'interface': 2,
#          'engine': 2,
#          'structured': 2,
#          'obesity': 2,
#          'unsupervised': 2,
#          'accidental': 2,
#          'cancer': 2,
#          'davidowitz': 2,
#          'defining': 2,
#          'laboratory': 2,
#          'simplify': 2,
#          'fit': 2,
#          'editor': 2,
#          'missing': 2,
#          'omics': 2,
#          'sandy': 2,
#          'loss': 2,
#          'theft': 2,
#          'ecology': 2,
#          'interoperability': 2,
#          'optimizing': 2,
#          'may': 2,
#          'harness': 2,
#          'cycle': 2,
#          'menopause': 2,
#          'related': 2,
#          'functional': 2,
#          'printing': 2,
#          'analyze': 2,
#          'coverage': 2,
#          'bipolar': 2,
#          'gpu': 2,
#          'array': 2,
#          'author': 2,
#          'response': 2,
#          'moving': 2,
#          'frontier': 2,
#          'lost': 2,
#          'sentinel': 2,
#          ...})

# %%
word_count = dict()

for tag, counts in count.most_common(50):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# data : 1645
# big : 1354
# analytics : 137
# analysis : 67
# based : 62
# using : 57
# system : 50
# science : 50
# management : 48
# challenge : 47
# approach : 44
# mining : 40
# new : 38
# research : 38
# health : 37
# model : 37
# cloud : 34
# smart : 34
# learning : 33
# opportunity : 31
# processing : 30
# technology : 28
# small : 27
# framework : 26
# information : 26
# computing : 25
# application : 25
# driven : 24
# social : 24
# issue : 24
# quality : 23
# network : 23
# deal : 23
# knowledge : 22
# efficient : 22
# review : 22
# use : 22
# era : 22
# healthcare : 21
# storage : 21
# service : 21
# perspective : 21
# open : 20
# platform : 19
# survey : 19
# making : 19
# process : 19
# distributed : 18
# large : 18
# environment : 18

# %%
#검색어로 사용한 'big'과 'data' 항목 제거 하기
del word_count['big']
del word_count['data']

# %%
# 히스토그램 표시 옵션 
plt.figure(figsize=(12,5))
plt.xlabel("word")
plt.ylabel("count")
plt.grid(True)

sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(), reverse=True)

plt.bar(range(len(word_count)), sorted_Values, align='center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation='90')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 11
#       8 sorted_Values = sorted(word_count.values(), reverse=True)
#      10 plt.bar(range(len(word_count)), sorted_Values, align='center')
# ---> 11 plt.xticks(range(len(word_count)), list(sorted_Keys), rotation='90')
#      13 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2053, in xticks(ticks, labels, minor, **kwargs)
#    2051         l._internal_update(kwargs)
#    2052 else:
# -> 2053     labels_out = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    2055 return locs, labels_out
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:2060, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2058 # deal with label1
#    2059 tick.label1.set_text(tick_label)
# -> 2060 tick.label1._internal_update(kwargs)
#    2061 # deal with label2
#    2062 tick.label2.set_text(tick_label)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1195, in Artist._update_props(self, props, errfmt)
#    1192             if not callable(func):
#    1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
# -> 1195             ret.append(func(v))
#    1196 if ret:
#    1197     self.pchanged()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\text.py:1231, in Text.set_rotation(self, s)
#    1229     self._rotation = 90.
#    1230 else:
# -> 1231     raise ValueError("rotation must be 'vertical', 'horizontal' or "
#    1232                      f"a number, not {s}")
#    1233 self.stale = True
#
# ValueError: rotation must be 'vertical', 'horizontal' or a number, not 90

# %%
# 히스토그램 표시 옵션 
plt.figure(figsize=(12,5))
plt.xlabel("word")
plt.ylabel("count")
plt.grid(True)

sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(), reverse=True)

plt.bar(range(len(word_count)), sorted_Values, align='center')
plt.xticks(range(len(word_count)), list(sorted_Keys), 'rotation=85')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 11
#       8 sorted_Values = sorted(word_count.values(), reverse=True)
#      10 plt.bar(range(len(word_count)), sorted_Values, align='center')
# ---> 11 plt.xticks(range(len(word_count)), list(sorted_Keys), 'rotation=85')
#      13 plt.show()
#
# TypeError: xticks() takes from 0 to 2 positional arguments but 3 were given

# %%
# 히스토그램 표시 옵션 
plt.figure(figsize=(12,5))
plt.xlabel("word")
plt.ylabel("count")
plt.grid(True)

sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(), reverse=True)

plt.bar(range(len(word_count)), sorted_Values, align='center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation=85)

plt.show()

# %%
all_files_data_concat['doc_count'] = 0
summary_year = all_files_data_concat.groupby('출판일', as_index=False)['doc_count'].count()
summary_year  #출력하여 내용 확인
# Out:
#      출판일  doc_count
# 0   1994          1
# 1   1995          1
# 2   1996          1
# 3   1998          3
# 4   2002          4
# 5   2003          1
# 6   2004          3
# 7   2005          3
# 8   2007          2
# 9   2008          3
# 10  2009          2
# 11  2010          3
# 12  2011          8
# 13  2012         34
# 14  2013         87
# 15  2014        154
# 16  2015        114
# 17  2016        139
# 18  2017        158
# 19  2018        130
# 20  2019        106
# 21  2020         43

# %%
plt.figure(figsize=(12,5))
plt.xlabel("year")
plt.ylabel("doc-count")
plt.grid(True)

plt.plot(range(len(summary_year)), summary_year['doc_count'])
plt.xticks(range(len(summary_year)), [text for text in summary_year['출판일']])

plt.show()

# %%
stopwords=set(STOPWORDS)
wc=WordCloud(background_color='ivory', stopwords=stopwords, width=800, height=600)
cloud=wc.generate_from_frequencies(word_count)

plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
cloud.to_file("C:/Users/PC/Desktop/My_Python/8장_data/riss_bigdata_wordCloud.jpg")
